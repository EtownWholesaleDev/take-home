# %% [markdown]
# <a href="https://colab.research.google.com/github/EtownWholesaleDev/take-home/blob/main/SKU_Image_Export_from_the_Bigcommerce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
import json
from typing import List, Dict, Optional
import time
from datetime import datetime

# Install required packages (run this cell first in Colab)
# !pip install requests pandas

# Configuration - Replace with your actual store details
STORE_HASH = "6knvqcnb7q"  # Found in your store URL
API_TOKEN = "hrxux0mjrpcve5jtj7dc8g5vneaet9t"    # Generate from Advanced Settings > API Accounts
API_VERSION = "v3"

# API Headers
headers = {
    'X-Auth-Token': API_TOKEN,
    'Content-Type': 'application/json',
    'Accept': 'application/json'
}

def get_variant_images(product_id: int, variant_id: int) -> List[Dict]:
    """
    Get images specifically associated with a variant
    """
    url = f"https://api.bigcommerce.com/stores/{STORE_HASH}/{API_VERSION}/catalog/products/{product_id}/variants/{variant_id}"

    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        variant_data = response.json().get('data', {})

        # Get the image_url field which is the variant-specific image
        variant_image = variant_data.get('image_url', '')

        return variant_image
    except requests.exceptions.RequestException as e:
        print(f"Error fetching variant {variant_id} for product {product_id}: {e}")
        return None

def get_product_images(product_id: int) -> List[Dict]:
    """
    Get all images for a specific product
    """
    url = f"https://api.bigcommerce.com/stores/{STORE_HASH}/{API_VERSION}/catalog/products/{product_id}/images"

    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        return response.json().get('data', [])
    except requests.exceptions.RequestException as e:
        print(f"Error fetching images for product {product_id}: {e}")
        return []

def match_variant_to_image(variant_image_url: str, product_images: List[Dict]) -> Optional[Dict]:
    """
    Match a variant's image URL to the full image data from product images
    """
    if not variant_image_url or not product_images:
        return None

    # BigCommerce variant image_url is often a thumbnail or modified version
    # We need to match it to the actual image in the product images list
    for img in product_images:
        # Check if the variant image URL contains the image filename or matches any URL format
        if (img.get('url_thumbnail', '') in variant_image_url or
            img.get('url_standard', '') in variant_image_url or
            variant_image_url in img.get('url_thumbnail', '') or
            variant_image_url in img.get('url_standard', '')):
            return img

    # If no exact match, return a basic structure with the variant image URL
    return {
        'id': None,
        'url_standard': variant_image_url,
        'url_thumbnail': variant_image_url,
        'url_zoom': variant_image_url,
        'sort_order': 0,
        'is_thumbnail': False
    }

def get_all_sku_specific_images():
    """
    Fetch all products and extract SKU-specific images (variant images only)
    """
    base_url = f"https://api.bigcommerce.com/stores/{STORE_HASH}/{API_VERSION}/catalog/products"

    all_sku_image_data = []
    page = 1
    limit = 250  # Maximum allowed per request

    print("Starting to fetch products with variant-specific images...")
    print("=" * 60)

    while True:
        params = {
            'page': page,
            'limit': limit,
            'include': 'variants'  # Include variants
        }

        try:
            response = requests.get(base_url, headers=headers, params=params)
            response.raise_for_status()
            data = response.json()
            products = data.get('data', [])

            if not products:
                print(f"\nNo more products found. Finished at page {page-1}.")
                break

            print(f"\nProcessing page {page} - {len(products)} products...")

            for product in products:
                product_id = product['id']
                product_name = product['name']
                product_sku = product.get('sku', '')

                # Get all product images once for matching
                product_images = get_product_images(product_id)
                time.sleep(0.2)  # Rate limiting

                # Process variants (which have individual SKUs)
                variants = product.get('variants', [])

                if variants:
                    print(f"  Product: {product_name} (ID: {product_id}) - {len(variants)} variants")

                    for variant in variants:
                        variant_id = variant['id']
                        variant_sku = variant.get('sku', '')

                        if not variant_sku:
                            continue

                        # Get the variant-specific image URL
                        variant_image_url = get_variant_images(product_id, variant_id)
                        time.sleep(0.2)  # Rate limiting

                        if variant_image_url:
                            # Try to match to full image data
                            matched_image = match_variant_to_image(variant_image_url, product_images)

                            if matched_image:
                                all_sku_image_data.append({
                                    'sku': variant_sku,
                                    'product_id': product_id,
                                    'product_name': product_name,
                                    'variant_id': variant_id,
                                    'image_id': matched_image.get('id'),
                                    'image_url_standard': matched_image.get('url_standard', ''),
                                    'image_url_thumbnail': matched_image.get('url_thumbnail', ''),
                                    'image_url_zoom': matched_image.get('url_zoom', ''),
                                    'is_thumbnail': matched_image.get('is_thumbnail', False),
                                    'sort_order': matched_image.get('sort_order', 0)
                                })
                                print(f"    ✓ SKU: {variant_sku} - Image found")
                            else:
                                print(f"    ✗ SKU: {variant_sku} - Image URL found but couldn't match to full data")
                        else:
                            # Variant exists but has no specific image
                            all_sku_image_data.append({
                                'sku': variant_sku,
                                'product_id': product_id,
                                'product_name': product_name,
                                'variant_id': variant_id,
                                'image_id': None,
                                'image_url_standard': 'NO VARIANT IMAGE',
                                'image_url_thumbnail': 'NO VARIANT IMAGE',
                                'image_url_zoom': 'NO VARIANT IMAGE',
                                'is_thumbnail': False,
                                'sort_order': 0
                            })
                            print(f"    ⚠ SKU: {variant_sku} - No variant-specific image")
                else:
                    # Product has no variants, only base product with SKU
                    if product_sku:
                        print(f"  Product: {product_name} (ID: {product_id}) - No variants (base product only)")

                        # For products without variants, we can optionally include the main product image
                        if product_images:
                            # Get the thumbnail/primary image
                            primary_image = next((img for img in product_images if img.get('is_thumbnail', False)),
                                                product_images[0] if product_images else None)

                            if primary_image:
                                all_sku_image_data.append({
                                    'sku': product_sku,
                                    'product_id': product_id,
                                    'product_name': product_name,
                                    'variant_id': None,
                                    'image_id': primary_image.get('id'),
                                    'image_url_standard': primary_image.get('url_standard', ''),
                                    'image_url_thumbnail': primary_image.get('url_thumbnail', ''),
                                    'image_url_zoom': primary_image.get('url_zoom', ''),
                                    'is_thumbnail': primary_image.get('is_thumbnail', False),
                                    'sort_order': primary_image.get('sort_order', 0)
                                })

            page += 1
            time.sleep(0.5)  # Rate limiting between pages

        except requests.exceptions.RequestException as e:
            print(f"\n❌ Error on page {page}: {e}")
            break

    return all_sku_image_data

def export_to_csv(data: List[Dict], filename='bigcommerce_sku_specific_images.csv'):
    """
    Export the SKU-specific image data to CSV
    """
    if not data:
        print("\n❌ No data to export!")
        return None

    df = pd.DataFrame(data)

    # Sort by SKU
    df = df.sort_values(['sku', 'sort_order'])

    # Save to CSV
    df.to_csv(filename, index=False)

    print("\n" + "=" * 60)
    print("✓ EXPORT COMPLETE")
    print("=" * 60)
    print(f"File saved: {filename}")
    print(f"Total records: {len(df)}")
    print(f"Unique SKUs: {df['sku'].nunique()}")
    print(f"SKUs with images: {len(df[df['image_url_standard'] != 'NO VARIANT IMAGE'])}")
    print(f"SKUs without images: {len(df[df['image_url_standard'] == 'NO VARIANT IMAGE'])}")

    # Show preview
    print("\n" + "=" * 60)
    print("PREVIEW OF DATA:")
    print("=" * 60)
    print(df.head(10).to_string())

    # Show some statistics
    print("\n" + "=" * 60)
    print("SAMPLE SKUs:")
    print("=" * 60)
    for idx, row in df.head(5).iterrows():
        print(f"\nSKU: {row['sku']}")
        print(f"  Product: {row['product_name']}")
        print(f"  Variant ID: {row['variant_id']}")
        print(f"  Image: {row['image_url_thumbnail'][:80]}...")

    return df

# Main execution
if __name__ == "__main__":
    print("\n" + "=" * 60)
    print("BigCommerce SKU-SPECIFIC Image Export Tool")
    print("(Variant Images Only)")
    print("=" * 60)

    # Validate configuration
    if STORE_HASH == "your_store_hash_here" or API_TOKEN == "your_api_token_here":
        print("\n❌ ERROR: Please update STORE_HASH and API_TOKEN with your actual values!")
    else:
        print(f"\nStore Hash: {STORE_HASH}")
        print(f"API Version: {API_VERSION}")
        print(f"Start Time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

        # Fetch data
        sku_image_data = get_all_sku_specific_images()

        # Export to CSV
        if sku_image_data:
            df = export_to_csv(sku_image_data)

            # Create additional summary report
            print("\n" + "=" * 60)
            print("Creating summary report...")

            if df is not None:
                summary_df = df.groupby('sku').agg({
                    'product_name': 'first',
                    'variant_id': 'first',
                    'image_url_standard': 'first',
                    'image_url_thumbnail': 'first'
                }).reset_index()

                summary_filename = 'sku_images_summary.csv'
                summary_df.to_csv(summary_filename, index=False)
                print(f"✓ Summary saved to '{summary_filename}'")
        else:
            print("\n❌ No data retrieved. Please check:")
            print("  1. Your API credentials are correct")
            print("  2. Your store hash is correct")
            print("  3. You have products with variants in your store")
            print("  4. Your API token has 'Products' read permissions")

        print(f"\nEnd Time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
        print("=" * 60)
# Out:
# Streaming output truncated to the last 5000 lines.
#     ✓ SKU: 54826 - Image found
#     ✓ SKU: 54827 - Image found
#     ✓ SKU: 54828 - Image found
#     ✓ SKU: 54829 - Image found
#   Product: Half Bak'd THC-A 2g Cart (ID: 1544) - 5 variants
#     ✓ SKU: 54831 - Image found
#     ✓ SKU: 54832 - Image found
#     ✓ SKU: 54833 - Image found
#     ✓ SKU: 54834 - Image found
#     ✓ SKU: 54889 - Image found
#   Product: Cake Glow 3g Cartridges (ID: 1545) - 12 variants
#     ✓ SKU: 55188 - Image found
#     ✓ SKU: 55189 - Image found
#     ✓ SKU: 55190 - Image found
#     ✓ SKU: 55191 - Image found
#     ✓ SKU: 55192 - Image found
#     ✓ SKU: 55193 - Image found
#     ✓ SKU: 55194 - Image found
#     ✓ SKU: 55195 - Image found
#     ✓ SKU: 55196 - Image found
#     ✓ SKU: 55197 - Image found
#     ✓ SKU: 55198 - Image found
#     ✓ SKU: 55199 - Image found
#   Product: Cake Stax 3g Disposable (ID: 1546) - 12 variants
#     ✓ SKU: 55200 - Image found
#     ✓ SKU: 55201 - Image found
#     ✓ SKU: 55202 - Image found
#     ✓ SKU: 55203 - Image found
#     ✓ SKU: 55204 - Image found
#     ✓ SKU: 55205 - Image found
#     ✓ SKU: 55206 - Image found
#     ✓ SKU: 55207 - Image found
#     ✓ SKU: 55208 - Image found
#     ✓ SKU: 55209 - Image found
#     ✓ SKU: 55210 - Image found
#     ✓ SKU: 55285 - Image found
#   Product: Cake Glow 3g Disposable (ID: 1547) - 12 variants
#     ✓ SKU: 55211 - Image found
#     ✓ SKU: 55212 - Image found
#     ✓ SKU: 55213 - Image found
#     ✓ SKU: 55214 - Image found
#     ✓ SKU: 55215 - Image found
#     ✓ SKU: 55216 - Image found
#     ✓ SKU: 55217 - Image found
#     ✓ SKU: 55218 - Image found
#     ✓ SKU: 55219 - Image found
#     ✓ SKU: 55220 - Image found
#     ✓ SKU: 55221 - Image found
#     ✓ SKU: 55222 - Image found
#   Product: Cake Delta 8/10 Gummies 10ct Box (ID: 1548) - 4 variants
#     ✓ SKU: 55386 - Image found
#     ✓ SKU: 55389 - Image found
#     ✓ SKU: 55390 - Image found
#     ✓ SKU: 55391 - Image found
#   Product: MRKTPLCE STND (ID: 1549) - 8 variants
#     ✓ SKU: 35495 - Image found
#     ✓ SKU: 35496 - Image found
#     ✓ SKU: 35497 - Image found
#     ✓ SKU: 35498 - Image found
#     ✓ SKU: 35494 - Image found
#     ✓ SKU: 51143 - Image found
#     ✓ SKU: 35491 - Image found
#     ✓ SKU: 35492 - Image found
#   Product: Lookah Seahorse (ID: 1550) - 8 variants
#     ✓ SKU: 55486 - Image found
#     ✓ SKU: 55487 - Image found
#     ✓ SKU: 55488 - Image found
#     ✓ SKU: 55489 - Image found
#     ✓ SKU: 55490 - Image found
#     ✓ SKU: 55491 - Image found
#     ✓ SKU: 55492 - Image found
#     ✓ SKU: 55493 - Image found
#   Product: Lookah Seahorse Limited Edition (ID: 1551) - 3 variants
#     ✓ SKU: 55495 - Image found
#     ✓ SKU: 55496 - Image found
#     ✓ SKU: 55497 - Image found
#   Product: Lookah Seahorse Pro (ID: 1552) - 5 variants
#     ✓ SKU: 55499 - Image found
#     ✓ SKU: 55500 - Image found
#     ✓ SKU: 55501 - Image found
#     ✓ SKU: 55502 - Image found
#     ✓ SKU: 55503 - Image found
#   Product: Lookah Seahorse Pro Limited Edition (ID: 1553) - 2 variants
#     ✓ SKU: 55505 - Image found
#     ✓ SKU: 55506 - Image found
#   Product: Lookah Seahorse Pro Plus Spatter Edition (ID: 1554) - 7 variants
#     ✓ SKU: 55508 - Image found
#     ✓ SKU: 55509 - Image found
#     ✓ SKU: 55510 - Image found
#     ✓ SKU: 55511 - Image found
#     ✓ SKU: 55512 - Image found
#     ✓ SKU: 55513 - Image found
#     ✓ SKU: 55514 - Image found
#   Product: Lookah Seahorse Coil (ID: 1555) - 6 variants
#     ✓ SKU: 55516 - Image found
#     ✓ SKU: 55517 - Image found
#     ✓ SKU: 55518 - Image found
#     ✓ SKU: 55519 - Image found
#     ✓ SKU: 55520 - Image found
#     ✓ SKU: 55585 - Image found
#   Product: Lookah Quartz Connect Coil (ID: 1556) - 5 variants
#     ✓ SKU: 55522 - Image found
#     ✓ SKU: 55523 - Image found
#     ✓ SKU: 55524 - Image found
#     ✓ SKU: 55525 - Image found
#     ✓ SKU: 55526 - Image found
#   Product: Lookah Unicorn Quartz Coil (ID: 1557) - 2 variants
#     ✓ SKU: 55528 - Image found
#     ✓ SKU: 55529 - Image found
#   Product: Lookah Firebee Quartz Coil (ID: 1558) - 2 variants
#     ✓ SKU: 55531 - Image found
#     ✓ SKU: 55532 - Image found
#   Product: Lookah Load 510 Battery 25ct Display (ID: 1559) - 1 variants
#     ✓ SKU: 55533 - Image found
#   Product: Lookah Load Limited Edition 510 Battery 16ct Display (ID: 1560) - 1 variants
#     ✓ SKU: 55534 - Image found
#   Product: Yocan Lux Plus 12ct Display (ID: 1561) - 1 variants
#     ✓ SKU: 55536 - Image found
#   Product: Yocan Lux Max 12ct Display (ID: 1562) - 1 variants
#     ✓ SKU: 55538 - Image found
#   Product: Yocan Pillar Kit (ID: 1563) - 5 variants
#     ✓ SKU: 55540 - Image found
#     ✓ SKU: 55541 - Image found
#     ✓ SKU: 55542 - Image found
#     ✓ SKU: 55543 - Image found
#     ✓ SKU: 55544 - Image found
#   Product: Yocan Regen Kit (ID: 1564) - 6 variants
#     ✓ SKU: 55546 - Image found
#     ✓ SKU: 55547 - Image found
#     ✓ SKU: 55548 - Image found
#     ✓ SKU: 55549 - Image found
#     ✓ SKU: 55550 - Image found
#     ✓ SKU: 55551 - Image found
#   Product: Wulf Evolve Maxxx 3in1 Nectar Tip (ID: 1565) - 9 variants
#     ✓ SKU: 55553 - Image found
#     ✓ SKU: 55554 - Image found
#     ✓ SKU: 55555 - Image found
#     ✓ SKU: 55556 - Image found
#     ✓ SKU: 55557 - Image found
#     ✓ SKU: 55558 - Image found
#     ✓ SKU: 55559 - Image found
#     ✓ SKU: 55560 - Image found
#     ✓ SKU: 55586 - Image found
#   Product: Yocan Cubex TGT Quartz Coils 5ct Box (ID: 1566) - 1 variants
#     ✓ SKU: 55561 - Image found
#   Product: Yocan Evolve Quartz Dual Coil 5ct Box (ID: 1567) - 1 variants
#     ✓ SKU: 55562 - Image found
#   Product: Yocan Magneto Coils 5ct Box (ID: 1568) - 1 variants
#     ✓ SKU: 55563 - Image found
#   Product: Yocan Armor Quartz Dual Coils 5ct Box (ID: 1569) - 1 variants
#     ✓ SKU: 55564 - Image found
#   Product: Yocan Rex Coils 5ct Box (ID: 1570) - 1 variants
#     ✓ SKU: 55565 - Image found
#   Product: Yocan Falcon Pancake Coils 5ct Box (ID: 1571) - 1 variants
#     ✓ SKU: 55566 - Image found
#   Product: Yocan Evolve D Coils 5ct Box (ID: 1572) - 1 variants
#     ✓ SKU: 55567 - Image found
#   Product: Yocan Evolve D Plus Coils 5ct Box (ID: 1573) - 1 variants
#     ✓ SKU: 55568 - Image found
#   Product: Yocan Falcon Xtal Coils 5ct Box (ID: 1574) - 1 variants
#     ✓ SKU: 55569 - Image found
#   Product: Yocan Evolve Plus Quartz Dual Coils 5ct Box (ID: 1575) - 1 variants
#     ✓ SKU: 55570 - Image found
#   Product: Nugg Life Glass Cleaner 12ct Box (ID: 1576) - 2 variants
#     ✓ SKU: 55572 - Image found
#     ✓ SKU: 55573 - Image found
#   Product: POP Hit Battery 1100mah 30ct Display (ID: 1577) - 4 variants
#     ✓ SKU: 55686 - Image found
#     ✓ SKU: 55687 - Image found
#     ✓ SKU: 55688 - Image found
#     ✓ SKU: 55697 - Image found
#   Product: POP Hit Gear 2.0 Battery 20ct Display (ID: 1578) - 1 variants
#     ✓ SKU: 55690 - Image found
#   Product: POP Hit Time Battery 900mah 12ct Display (ID: 1579) - 1 variants
#     ✓ SKU: 55692 - Image found
#   Product: POP Hit Clear Battery 15ct Display (ID: 1580) - 1 variants
#     ✓ SKU: 55694 - Image found
#   Product: POP Hit Box 2.0 Battery 10ct Display (ID: 1581) - 1 variants
#     ✓ SKU: 55696 - Image found
#   Product: Lookah Straw Metal Kit (ID: 1582) - 1 variants
#     ✓ SKU: 55698 - Image found
#   Product: Yocan Evolve Coil 5ct Box (ID: 1583) - 2 variants
#     ✓ SKU: 55886 - Image found
#     ✓ SKU: 55887 - Image found
#   Product: Yocan Evolve Plus Coil 5ct Box (ID: 1584) - 2 variants
#     ✓ SKU: 55888 - Image found
#     ✓ SKU: 55889 - Image found
#   Product: Yocan Evolve Maxxx 3in1 Replacement (ID: 1585) - 1 variants
#     ✓ SKU: 55986 - Image found
#   Product: Tasty Puff Tips 72ct Display (ID: 1586) - 1 variants
#     ✓ SKU: 56090 - Image found
#   Product: Cryo Kratom 20ct Box (ID: 1587) - 1 variants
#     ✓ SKU: 56498 - Image found
#   Product: Half Bak'd Cosmic Conez 2ct Bag (ID: 1588) - 4 variants
#     ✓ SKU: 56599 - Image found
#     ✓ SKU: 56600 - Image found
#     ✓ SKU: 56601 - Image found
#     ✓ SKU: 56602 - Image found
#   Product: Half Bak'd Live Resin Purifry'd THC-A Diamond DAB (ID: 1589) - 4 variants
#     ✓ SKU: 56607 - Image found
#     ✓ SKU: 56604 - Image found
#     ✓ SKU: 56605 - Image found
#     ✓ SKU: 56606 - Image found
#   Product: Half Bak'd Live Resin Sauce'd Exotix THC-P 4G Disposables (ID: 1590) - 6 variants
#     ✓ SKU: 56609 - Image found
#     ✓ SKU: 56611 - Image found
#     ✓ SKU: 56610 - Image found
#     ⚠ SKU: 63674 - No variant-specific image
#     ⚠ SKU: 63675 - No variant-specific image
#     ⚠ SKU: 63676 - No variant-specific image
#   Product: Geekvape Wenax K2 Kit (ID: 1592) - 6 variants
#     ✓ SKU: 56699 - Image found
#     ✓ SKU: 56700 - Image found
#     ✓ SKU: 56701 - Image found
#     ✓ SKU: 56702 - Image found
#     ✓ SKU: 56703 - Image found
#     ✓ SKU: 56704 - Image found
#   Product: Geekvape Q Pod 1.2ohm 3ct (ID: 1593) - 1 variants
#     ✓ SKU: 56705 - Image found
#   Product: Geekvape Aegis Hero 2 H45 Kit (ID: 1594) - 4 variants
#     ✓ SKU: 56709 - Image found
#     ⚠ SKU: 69291 - No variant-specific image
#     ⚠ SKU: 69292 - No variant-specific image
#     ⚠ SKU: 69290 - No variant-specific image
#   Product: Geekvape Wenax K1 Pod (ID: 1595) - 5 variants
#     ✓ SKU: 56711 - Image found
#     ✓ SKU: 56712 - Image found
#     ✓ SKU: 56713 - Image found
#     ✓ SKU: 56714 - Image found
#     ✓ SKU: 56715 - Image found
#   Product: Cannabis Life D8 Gummies 750mg 30ct Jar (ID: 1596) - 5 variants
#     ✓ SKU: 56799 - Image found
#     ✓ SKU: 56800 - Image found
#     ✓ SKU: 56801 - Image found
#     ✓ SKU: 56802 - Image found
#     ✓ SKU: 56803 - Image found
#   Product: Cannabis Life D8 Gummies 1500mg 30ct Jar (ID: 1597) - 4 variants
#     ✓ SKU: 56805 - Image found
#     ✓ SKU: 56806 - Image found
#     ✓ SKU: 56807 - Image found
#     ✓ SKU: 56808 - Image found
#   Product: Geekvape B Series Coil (ID: 1598) - 5 variants
#     ✓ SKU: 56717 - Image found
#     ✓ SKU: 56721 - Image found
#     ✓ SKU: 56718 - Image found
#     ✓ SKU: 56720 - Image found
#     ✓ SKU: 56719 - Image found
#   Product: Green Monkey Grinder Capuchin (ID: 1599) - 6 variants
#     ✓ SKU: 56301 - Image found
#     ✓ SKU: 56299 - Image found
#     ✓ SKU: 56199 - Image found
#     ✓ SKU: 56298 - Image found
#     ✓ SKU: 56302 - Image found
#     ✓ SKU: 56300 - Image found
#   Product: Galaxy Treats THC-A Disposable 5g (ID: 1600) - 4 variants
#     ✓ SKU: 56616 - Image found
#     ✓ SKU: 56614 - Image found
#     ✓ SKU: 56615 - Image found
#     ✓ SKU: 56613 - Image found
#   Product: Kado 10k Puff Black Edition (ID: 1602) - 10 variants
#     ✓ SKU: 57121 - Image found
#     ✓ SKU: 57119 - Image found
#     ✓ SKU: 57115 - Image found
#     ✓ SKU: 57120 - Image found
#     ✓ SKU: 57123 - Image found
#     ✓ SKU: 57122 - Image found
#     ✓ SKU: 57117 - Image found
#     ✓ SKU: 57116 - Image found
#     ✓ SKU: 57214 - Image found
#     ✓ SKU: 57118 - Image found
#   Product: MTRX MX 25000puff (ID: 1603) - 14 variants
#     ✓ SKU: 57323 - Image found
#     ✓ SKU: 57324 - Image found
#     ✓ SKU: 57325 - Image found
#     ✓ SKU: 57326 - Image found
#     ✓ SKU: 57327 - Image found
#     ✓ SKU: 57328 - Image found
#     ✓ SKU: 57329 - Image found
#     ✓ SKU: 57330 - Image found
#     ✓ SKU: 57331 - Image found
#     ✓ SKU: 57332 - Image found
#     ✓ SKU: 57333 - Image found
#     ✓ SKU: 57334 - Image found
#     ✓ SKU: 57335 - Image found
#     ✓ SKU: 57336 - Image found
#   Product: Vaporesso Luxe Q Pod 1.0ohm 4ct 2ml (ID: 1604) - 1 variants
#     ✓ SKU: 57426 - Image found
#   Product: Vaporesso Luxe Q Pod 1.0ohm 4ct 3ml (ID: 1605) - 1 variants
#     ✓ SKU: 57427 - Image found
#   Product: Vaporesso Xros Pro Kit (ID: 1606) - 7 variants
#     ✓ SKU: 57431 - Image found
#     ✓ SKU: 57432 - Image found
#     ✓ SKU: 57433 - Image found
#     ✓ SKU: 57434 - Image found
#     ✓ SKU: 57435 - Image found
#     ✓ SKU: 57436 - Image found
#     ✓ SKU: 57437 - Image found
#   Product: Mystic Labs Kava Kava Gummies 6ct Box (ID: 1615) - 2 variants
#     ✓ SKU: 57846 - Image found
#     ✓ SKU: 57847 - Image found
#   Product: Kado 20K Puff Vintage Edition (ID: 1616) - 10 variants
#     ✓ SKU: 57952 - Image found
#     ✓ SKU: 57950 - Image found
#     ✓ SKU: 57948 - Image found
#     ✓ SKU: 57946 - Image found
#     ✓ SKU: 57947 - Image found
#     ✓ SKU: 57953 - Image found
#     ✓ SKU: 57954 - Image found
#     ✓ SKU: 57951 - Image found
#     ✓ SKU: 57955 - Image found
#     ✓ SKU: 57949 - Image found
#   Product: Raz DC25000 (ID: 1617) - 37 variants
#     ✓ SKU: 58057 - Image found
#     ✓ SKU: 58049 - Image found
#     ✓ SKU: 58048 - Image found
#     ✓ SKU: 58053 - Image found
#     ✓ SKU: 58051 - Image found
#     ✓ SKU: 58055 - Image found
#     ✓ SKU: 58050 - Image found
#     ✓ SKU: 58046 - Image found
#     ✓ SKU: 58052 - Image found
#     ✓ SKU: 58054 - Image found
#     ✓ SKU: 58346 - Image found
#     ✓ SKU: 58058 - Image found
#     ✓ SKU: 58059 - Image found
#     ✓ SKU: 58047 - Image found
#     ✓ SKU: 58056 - Image found
#     ✓ SKU: 62660 - Image found
#     ✓ SKU: 62659 - Image found
#     ✓ SKU: 62658 - Image found
#     ✓ SKU: 62657 - Image found
#     ✓ SKU: 62656 - Image found
#     ✓ SKU: 64788 - Image found
#     ✓ SKU: 64790 - Image found
#     ✓ SKU: 64791 - Image found
#     ✓ SKU: 64792 - Image found
#     ✓ SKU: 64794 - Image found
#     ✓ SKU: 64793 - Image found
#     ✓ SKU: 65010 - Image found
#     ✓ SKU: 65011 - Image found
#     ✓ SKU: 65012 - Image found
#     ✓ SKU: 66558 - Image found
#     ✓ SKU: 66560 - Image found
#     ✓ SKU: 66559 - Image found
#     ✓ SKU: 66557 - Image found
#     ⚠ SKU: 67575 - No variant-specific image
#     ⚠ SKU: 67574 - No variant-specific image
#     ⚠ SKU: 64584 - No variant-specific image
#     ⚠ SKU: 67573 - No variant-specific image
#   Product: Nano K (ID: 1619) - 5 variants
#     ✓ SKU: 39823 - Image found
#     ✓ SKU: 42016 - Image found
#     ⚠ SKU: 57842 - No variant-specific image
#     ✓ SKU: 57843 - Image found
#     ⚠ SKU: 57844 - No variant-specific image
#   Product: Vaporesso Luxe X 2ct Pod (ID: 1620) - 3 variants
#     ✓ SKU: 58364 - Image found
#     ✓ SKU: 58363 - Image found
#     ✓ SKU: 58365 - Image found
#   Product: Uwell Valyrian II Coil (ID: 1621) - 1 variants
#     ✓ SKU: 58367 - Image found
#   Product: Vaporesso Luxe Q2 SE Kit (ID: 1622) - 8 variants
#     ✓ SKU: 58369 - Image found
#     ✓ SKU: 58370 - Image found
#     ✓ SKU: 58371 - Image found
#     ✓ SKU: 58372 - Image found
#     ✓ SKU: 58373 - Image found
#     ✓ SKU: 58374 - Image found
#     ✓ SKU: 58375 - Image found
#     ✓ SKU: 58376 - Image found
#   Product: Vaporesso Luxe Q2 Kit (ID: 1623) - 5 variants
#     ✓ SKU: 58463 - Image found
#     ✓ SKU: 58464 - Image found
#     ✓ SKU: 58465 - Image found
#     ✓ SKU: 58466 - Image found
#     ✓ SKU: 58467 - Image found
#   Product: Vaporesso Luxe X Pro Kit (ID: 1624) - 7 variants
#     ✓ SKU: 58469 - Image found
#     ✓ SKU: 58470 - Image found
#     ✓ SKU: 58471 - Image found
#     ✓ SKU: 58472 - Image found
#     ✓ SKU: 58473 - Image found
#     ⚠ SKU: 62253 - No variant-specific image
#     ⚠ SKU: 62254 - No variant-specific image
#   Product: VooPoo Argus P2 Kit (ID: 1625) - 8 variants
#     ✓ SKU: 58475 - Image found
#     ✓ SKU: 58476 - Image found
#     ✓ SKU: 58477 - Image found
#     ✓ SKU: 58478 - Image found
#     ✓ SKU: 58479 - Image found
#     ✓ SKU: 58480 - Image found
#     ✓ SKU: 58481 - Image found
#     ✓ SKU: 58482 - Image found
#   Product: Geekvape H45 Pod 2ct (ID: 1626) - 1 variants
#     ✓ SKU: 58485 - Image found
#   Product: VooPoo Argus 2ml Pod (ID: 1627) - 2 variants
#     ✓ SKU: 58487 - Image found
#     ✓ SKU: 58488 - Image found
#   Product: Geekvape B60 Aegis Boost 2 Pod 2ct (ID: 1628) - 1 variants
#     ✓ SKU: 58483 - Image found
#   Product: Ultra Gold 12ct Box (ID: 1629) - 1 variants
#     ✓ SKU: 58563 - Image found
#   Product: Viva Zen 12ct Box - Raspberry (Women's Health Formula) (ID: 1630) - 1 variants
#     ✓ SKU: 58766 - Image found
#   Product: Juice Head Pouches PP1.99 6mg 5ct Roll (ID: 1631) - 5 variants
#     ✓ SKU: 58784 - Image found
#     ✓ SKU: 58785 - Image found
#     ✓ SKU: 58786 - Image found
#     ✓ SKU: 58787 - Image found
#     ✓ SKU: 58788 - Image found
#   Product: Mr Fog  Pouches 8mg 5ct Roll (ID: 1632) - 10 variants
#     ✓ SKU: 58790 - Image found
#     ✓ SKU: 58791 - Image found
#     ✓ SKU: 58792 - Image found
#     ✓ SKU: 58793 - Image found
#     ⚠ SKU: 61846 - No variant-specific image
#     ⚠ SKU: 61847 - No variant-specific image
#     ⚠ SKU: 61848 - No variant-specific image
#     ⚠ SKU: 61849 - No variant-specific image
#     ⚠ SKU: 61850 - No variant-specific image
#     ⚠ SKU: 62252 - No variant-specific image
#   Product: Colors Sheet Wraps 2pk 25ct Box (ID: 1633) - 12 variants
#     ✓ SKU: 58892 - Image found
#     ✓ SKU: 58992 - Image found
#     ✓ SKU: 58993 - Image found
#     ✓ SKU: 58994 - Image found
#     ✓ SKU: 59094 - Image found
#     ✓ SKU: 59095 - Image found
#     ✓ SKU: 59000 - Image found
#     ✓ SKU: 58999 - Image found
#     ✓ SKU: 59191 - Image found
#     ✓ SKU: 59291 - Image found
#     ✓ SKU: 59292 - Image found
#     ✓ SKU: 59001 - Image found
#   Product: Suorin Air Pro 4.9ML 1ct Pod (ID: 1634) - 2 variants
#     ✓ SKU: 59392 - Image found
#     ✓ SKU: 59393 - Image found
#   Product: Krave 2oz 12ct Box (ID: 1635) - 1 variants
#     ✓ SKU: 59501 - Image found
#   Product: Juice Monster 100ml (ID: 1636) - 12 variants
#     ✓ SKU: 59806 - Image found
#     ✓ SKU: 59807 - Image found
#     ✓ SKU: 59808 - Image found
#     ✓ SKU: 59809 - Image found
#     ✓ SKU: 59810 - Image found
#     ✓ SKU: 59811 - Image found
#     ✓ SKU: 59905 - Image found
#     ✓ SKU: 59906 - Image found
#     ✓ SKU: 59907 - Image found
#     ✓ SKU: 59908 - Image found
#     ✓ SKU: 59909 - Image found
#     ✓ SKU: 59910 - Image found
#   Product: Juice Monster Salts 30ml (ID: 1637) - 12 variants
#     ✓ SKU: 59813 - Image found
#     ✓ SKU: 59814 - Image found
#     ✓ SKU: 59815 - Image found
#     ✓ SKU: 59816 - Image found
#     ✓ SKU: 59817 - Image found
#     ✓ SKU: 59818 - Image found
#     ✓ SKU: 59911 - Image found
#     ✓ SKU: 59912 - Image found
#     ✓ SKU: 59913 - Image found
#     ✓ SKU: 59914 - Image found
#     ✓ SKU: 59915 - Image found
#     ✓ SKU: 59916 - Image found
#   Product: Viva Zen Kava + Kratom 12ct Box (ID: 1638) - 1 variants
#     ✓ SKU: 60015 - Image found
#   Product: Viva Zen Ultimate Honey 15ml Shots 12ct Box (ID: 1639) - 1 variants
#     ✓ SKU: 60016 - Image found
#   Product: Viva Zen Ultimate Honey 30ml Pouch 12ct Box (ID: 1640) - 1 variants
#     ✓ SKU: 60017 - Image found
#   Product: Hidden Hills Heady Blend 2g Cart (ID: 1641) - 4 variants
#     ✓ SKU: 60118 - Image found
#     ✓ SKU: 60217 - Image found
#     ✓ SKU: 60218 - Image found
#     ✓ SKU: 60219 - Image found
#   Product: Hidden Hills Heady Blend 2g Disposable (ID: 1642) - 4 variants
#     ✓ SKU: 60220 - Image found
#     ✓ SKU: 60221 - Image found
#     ✓ SKU: 60222 - Image found
#     ✓ SKU: 60223 - Image found
#   Product: Hidden Hills and Friends 2g Disposable (ID: 1643) - 3 variants
#     ✓ SKU: 60224 - Image found
#     ✓ SKU: 60225 - Image found
#     ✓ SKU: 60226 - Image found
#   Product: Kado Hexabar 20K Puffs (ID: 1644) - 27 variants
#     ✓ SKU: 58247 - Image found
#     ✓ SKU: 58249 - Image found
#     ✓ SKU: 58246 - Image found
#     ✓ SKU: 58149 - Image found
#     ✓ SKU: 58253 - Image found
#     ✓ SKU: 58147 - Image found
#     ✓ SKU: 58251 - Image found
#     ✓ SKU: 58250 - Image found
#     ✓ SKU: 58252 - Image found
#     ✓ SKU: 58248 - Image found
#     ✓ SKU: 58148 - Image found
#     ✓ SKU: 58254 - Image found
#     ✓ SKU: 62961 - Image found
#     ✓ SKU: 62962 - Image found
#     ✓ SKU: 62963 - Image found
#     ✓ SKU: 62964 - Image found
#     ✓ SKU: 62965 - Image found
#     ✓ SKU: 62966 - Image found
#     ✓ SKU: 62967 - Image found
#     ✓ SKU: 62968 - Image found
#     ✓ SKU: 62969 - Image found
#     ✓ SKU: 62970 - Image found
#     ✓ SKU: 62971 - Image found
#     ✓ SKU: 62972 - Image found
#     ✓ SKU: 62973 - Image found
#     ✓ SKU: 62974 - Image found
#     ✓ SKU: 62975 - Image found
#   Product: Smoke Odor XXX 1oz 12ct Box (ID: 1645) - 7 variants
#     ⚠ SKU: 60519 - No variant-specific image
#     ⚠ SKU: 60520 - No variant-specific image
#     ⚠ SKU: 60521 - No variant-specific image
#     ⚠ SKU: 60522 - No variant-specific image
#     ⚠ SKU: 60523 - No variant-specific image
#     ⚠ SKU: 60718 - No variant-specific image
#     ⚠ SKU: 60818 - No variant-specific image
#   Product: Geekbar Pulse X 25K (ID: 1646) - 20 variants
#     ✓ SKU: 60619 - Image found
#     ✓ SKU: 60620 - Image found
#     ✓ SKU: 60621 - Image found
#     ✓ SKU: 60622 - Image found
#     ✓ SKU: 60623 - Image found
#     ✓ SKU: 60624 - Image found
#     ✓ SKU: 60625 - Image found
#     ✓ SKU: 60626 - Image found
#     ✓ SKU: 60627 - Image found
#     ✓ SKU: 60628 - Image found
#     ✓ SKU: 60629 - Image found
#     ✓ SKU: 61633 - Image found
#     ✓ SKU: 61428 - Image found
#     ✓ SKU: 61635 - Image found
#     ✓ SKU: 61951 - Image found
#     ✓ SKU: 64180 - Image found
#     ✓ SKU: 64181 - Image found
#     ✓ SKU: 64182 - Image found
#     ✓ SKU: 64179 - Image found
#     ✓ SKU: 64283 - Image found
#   Product: ELF Hardware Box Concealer Battery 15ct Box (ID: 1647) - 1 variants
#     ✓ SKU: 60819 - Image found
#   Product: ELF Hardware Canndy Battery 15ct Box (ID: 1648) - 1 variants
#     ✓ SKU: 60820 - Image found
#   Product: ELF Hardware Deltaic Battery 15ct Box (ID: 1649) - 1 variants
#     ✓ SKU: 60821 - Image found
#   Product: ELF Hardware Twist Battery 15ct Box (ID: 1650) - 1 variants
#     ✓ SKU: 60822 - Image found
#   Product: Coca Cola Stash Can 12oz (ID: 1651) - 1 variants
#     ✓ SKU: 60825 - Image found
#   Product: Monster Energy Stash Can 16oz (ID: 1652) - 6 variants
#     ✓ SKU: 60827 - Image found
#     ✓ SKU: 60920 - Image found
#     ✓ SKU: 60921 - Image found
#     ✓ SKU: 60922 - Image found
#     ✓ SKU: 60923 - Image found
#     ✓ SKU: 61019 - Image found
#   Product: Arizona Stash Can 23oz (ID: 1654) - 1 variants
#     ✓ SKU: 60919 - Image found
#   Product: Mountain Dew Stash Can 12oz (ID: 1655) - 2 variants
#     ✓ SKU: 60924 - Image found
#     ✓ SKU: 61634 - Image found
#   Product: 7Ohmz 3ct Capsules 20ct Box (ID: 1656) - 1 variants
#     ✓ SKU: 61119 - Image found
#   Product: Rhino 69 Liquid Shot 12ct Box (ID: 1657) - 1 variants
#     ✓ SKU: 61219 - Image found
#   Product: Black Panther Liquid Shot 12ct Box (ID: 1658) - 1 variants
#     ✓ SKU: 61220 - Image found
#   Product: Pink Push Cat Liquid Shot 12ct Box (ID: 1659) - 1 variants
#     ⚠ SKU: 61221 - No variant-specific image
#   Product: Black Panther 5000K 24ct Box (ID: 1660) - 1 variants
#     ✓ SKU: 61222 - Image found
#   Product: Black Mamba 5000K 24ct Box (ID: 1661) - 1 variants
#     ✓ SKU: 61223 - Image found
#   Product: Sow Good Freeze Dried Candy 3oz (ID: 1662) - 1 variants
#     ✓ SKU: 61321 - Image found
#   Product: PrimeZen Liquid Shot 12ct Box (ID: 1663) - 1 variants
#     ✓ SKU: 61322 - Image found
#   Product: Uwell Caliburn GK3 Tenet Kit (ID: 1664) - 7 variants
#     ✓ SKU: 61324 - Image found
#     ✓ SKU: 61325 - Image found
#     ✓ SKU: 61326 - Image found
#     ✓ SKU: 61327 - Image found
#     ✓ SKU: 61328 - Image found
#     ✓ SKU: 61329 - Image found
#     ✓ SKU: 61330 - Image found
#   Product: Vaporesso XROS Corex 2.0 Pod 4ct box (ID: 1665) - 7 variants
#     ✓ SKU: 61332 - Image found
#     ✓ SKU: 61333 - Image found
#     ⚠ SKU: 64815 - No variant-specific image
#     ⚠ SKU: 64816 - No variant-specific image
#     ⚠ SKU: 64817 - No variant-specific image
#     ⚠ SKU: 64818 - No variant-specific image
#     ⚠ SKU: 64819 - No variant-specific image
#   Product: Vaporesso XROS 4 Mini Kit (ID: 1666) - 10 variants
#     ✓ SKU: 61335 - Image found
#     ✓ SKU: 61336 - Image found
#     ✓ SKU: 61337 - Image found
#     ✓ SKU: 61338 - Image found
#     ✓ SKU: 61339 - Image found
#     ✓ SKU: 61340 - Image found
#     ✓ SKU: 61341 - Image found
#     ✓ SKU: 61342 - Image found
#     ✓ SKU: 64896 - Image found
#     ✓ SKU: 64895 - Image found
#   Product: Vaporesso XROS 4 Kit (ID: 1667) - 7 variants
#     ✓ SKU: 61344 - Image found
#     ✓ SKU: 61345 - Image found
#     ✓ SKU: 61346 - Image found
#     ✓ SKU: 61347 - Image found
#     ✓ SKU: 61348 - Image found
#     ✓ SKU: 61349 - Image found
#     ✓ SKU: 61350 - Image found
#   Product: Glass Nectar Collector 10mm (ID: 1668) - 4 variants
#     ✓ SKU: 61354 - Image found
#     ✓ SKU: 61355 - Image found
#     ✓ SKU: 61356 - Image found
#     ✓ SKU: 61357 - Image found
#   Product: Glass Nectar Collector 14mm (ID: 1669) - 8 variants
#     ⚠ SKU: 61359 - No variant-specific image
#     ⚠ SKU: 61424 - No variant-specific image
#     ⚠ SKU: 61425 - No variant-specific image
#     ⚠ SKU: 61426 - No variant-specific image
#     ⚠ SKU: 61423 - No variant-specific image
#     ⚠ SKU: 78009 - No variant-specific image
#     ⚠ SKU: 78010 - No variant-specific image
#     ⚠ SKU: 78011 - No variant-specific image
#   Product: Vaporesso XROS 4ct Pod 0.6ohm (ID: 1670) - 1 variants
#     ✓ SKU: 61352 - Image found
#   Product: Vaporesso XROS 4ct Pod 3ml 0.6ohm (ID: 1671) - 1 variants
#     ✓ SKU: 61351 - Image found
#   Product: Khali Vapor E-Liquid (ID: 1672) - 4 variants
#     ✓ SKU: 61430 - Image found
#     ⚠ SKU: 61431 - No variant-specific image
#     ✓ SKU: 61432 - Image found
#     ⚠ SKU: 61433 - No variant-specific image
#   Product: Hidden Hills Live Sugar 3G Disposable (ID: 1673) - 2 variants
#     ✓ SKU: 61637 - Image found
#     ✓ SKU: 61638 - Image found
#   Product: Hidden Hills Night Night Blend 2G Disposable (ID: 1674) - 2 variants
#     ✓ SKU: 61640 - Image found
#     ✓ SKU: 63876 - Image found
#   Product: Hidden Hills Shield Gummies 1000mg 2pk 20ct Box (ID: 1675) - 4 variants
#     ✓ SKU: 61642 - Image found
#     ✓ SKU: 63570 - Image found
#     ✓ SKU: 70491 - Image found
#     ⚠ SKU: 63569 - No variant-specific image
#   Product: Kado THC 6G Disposable (ID: 1676) - 6 variants
#     ✓ SKU: 61852 - Image found
#     ✓ SKU: 61853 - Image found
#     ✓ SKU: 61854 - Image found
#     ✓ SKU: 61855 - Image found
#     ✓ SKU: 61856 - Image found
#     ✓ SKU: 61857 - Image found
#   Product: Border Brothers 5g Diamond Sauce Dabs (ID: 1677) - 3 variants
#     ✓ SKU: 62053 - Image found
#     ✓ SKU: 62054 - Image found
#     ✓ SKU: 62055 - Image found
#   Product: Hidden Hills Fresh Fozen Badder 3g (ID: 1678) - 4 variants
#     ✓ SKU: 61953 - Image found
#     ✓ SKU: 61954 - Image found
#     ✓ SKU: 61955 - Image found
#     ✓ SKU: 61956 - Image found
#   Product: Blood Diamond 2g Duo Carts (ID: 1679) - 3 variants
#     ✓ SKU: 62057 - Image found
#     ✓ SKU: 62058 - Image found
#     ✓ SKU: 62059 - Image found
#   Product: Urban Tale Salts Eliquid (ID: 1680) - 24 variants
#     ✓ SKU: 62357 - Image found
#     ⚠ SKU: 62358 - No variant-specific image
#     ✓ SKU: 62359 - Image found
#     ⚠ SKU: 62360 - No variant-specific image
#     ✓ SKU: 62361 - Image found
#     ⚠ SKU: 62362 - No variant-specific image
#     ✓ SKU: 62363 - Image found
#     ⚠ SKU: 62364 - No variant-specific image
#     ✓ SKU: 62365 - Image found
#     ⚠ SKU: 62366 - No variant-specific image
#     ✓ SKU: 62367 - Image found
#     ⚠ SKU: 62368 - No variant-specific image
#     ✓ SKU: 62369 - Image found
#     ⚠ SKU: 62370 - No variant-specific image
#     ✓ SKU: 62371 - Image found
#     ⚠ SKU: 62372 - No variant-specific image
#     ✓ SKU: 62373 - Image found
#     ⚠ SKU: 62374 - No variant-specific image
#     ✓ SKU: 62375 - Image found
#     ⚠ SKU: 62376 - No variant-specific image
#     ✓ SKU: 62377 - Image found
#     ⚠ SKU: 62378 - No variant-specific image
#     ✓ SKU: 62379 - Image found
#     ⚠ SKU: 62380 - No variant-specific image
#   Product: Vaporesso Luxe X MTL Pod 5ml 2ct (ID: 1681) - 2 variants
#     ✓ SKU: 62762 - Image found
#     ✓ SKU: 62763 - Image found
#   Product: Vaporesso Luxe X DTL Pod 2ct (ID: 1682) - 1 variants
#     ✓ SKU: 62765 - Image found
#   Product: Coolioh! Freeze Dried Candy 2.4oz (ID: 1683) - 2 variants
#     ✓ SKU: 62862 - Image found
#     ✓ SKU: 62863 - Image found
#   Product: Coolioh Freeze Dried Candy 4oz (ID: 1684) - 2 variants
#     ✓ SKU: 62865 - Image found
#     ✓ SKU: 62866 - Image found
#   Product: Hyroxi 7ohm Kratom 4ct Tablet 20ct Box (ID: 1685) - 1 variants
#     ✓ SKU: 62867 - Image found
#   Product: Icon Kratom 300mg 15ml 12ct Box (ID: 1686) - 1 variants
#     ✓ SKU: 63063 - Image found
#   Product: Geekbar Skyview 25000puff (ID: 1687) - 15 variants
#     ✓ SKU: 63065 - Image found
#     ✓ SKU: 63066 - Image found
#     ✓ SKU: 63067 - Image found
#     ✓ SKU: 63068 - Image found
#     ✓ SKU: 63163 - Image found
#     ✓ SKU: 63364 - Image found
#     ✓ SKU: 63365 - Image found
#     ✓ SKU: 63367 - Image found
#     ✓ SKU: 63366 - Image found
#     ✓ SKU: 63976 - Image found
#     ✓ SKU: 63975 - Image found
#     ✓ SKU: 63977 - Image found
#     ✓ SKU: 63978 - Image found
#     ✓ SKU: 63872 - Image found
#     ✓ SKU: 63873 - Image found
#   Product: Royal Relax Kratom Extract 330mg 30ml Shot 12ct Box (ID: 1688) - 6 variants
#     ✓ SKU: 63166 - Image found
#     ✓ SKU: 63265 - Image found
#     ✓ SKU: 63264 - Image found
#     ✓ SKU: 63168 - Image found
#     ✓ SKU: 63165 - Image found
#     ✓ SKU: 63167 - Image found
#   Product: PureOhms Kratom Kava Shot 12ct Box (ID: 1689) - 1 variants
#     ✓ SKU: 63371 - Image found
#   Product: Rhino Choco 12ct Box (ID: 1690) - 1 variants
#     ✓ SKU: 63469 - Image found
#   Product: PureOhms Kratom 4ct Tablets 10ct Box (ID: 1691) - 1 variants
#     ✓ SKU: 63372 - Image found
#   Product: Half Bak'd Live Resin Sauce'd Exotix THC-P 2g Carts (ID: 1692) - 6 variants
#     ✓ SKU: 63572 - Image found
#     ✓ SKU: 63573 - Image found
#     ✓ SKU: 63574 - Image found
#     ✓ SKU: 63671 - Image found
#     ✓ SKU: 63672 - Image found
#     ✓ SKU: 63673 - Image found
#   Product: Hidden Hills Shatter Bar HHC Blend 3G Disposable (ID: 1693) - 2 variants
#     ✓ SKU: 63773 - Image found
#     ✓ SKU: 63772 - Image found
#   Product: Icon Kratom 500mg 15ml 12ct Box (ID: 1694) - 1 variants
#     ✓ SKU: 63877 - Image found
#   Product: Hidden Hills BFF Blend 2G Disposable (ID: 1695) - 3 variants
#     ✓ SKU: 63980 - Image found
#     ✓ SKU: 63981 - Image found
#     ✓ SKU: 63982 - Image found
#   Product: AirFuze Smart 30000puffs (ID: 1696) - 12 variants
#     ✓ SKU: 64080 - Image found
#     ✓ SKU: 64081 - Image found
#     ✓ SKU: 64082 - Image found
#     ✓ SKU: 64083 - Image found
#     ✓ SKU: 64084 - Image found
#     ✓ SKU: 64085 - Image found
#     ✓ SKU: 64086 - Image found
#     ✓ SKU: 64087 - Image found
#     ✓ SKU: 64088 - Image found
#     ✓ SKU: 64089 - Image found
#     ✓ SKU: 64906 - Image found
#     ✓ SKU: 64907 - Image found
#   Product: PureOhms Kratom Shot 12ct Box (ID: 1697) - 1 variants
#     ✓ SKU: 64184 - Image found
#   Product: Raz TN9000 NICOTINE FREE (ID: 1698) - 5 variants
#     ✓ SKU: 64285 - Image found
#     ✓ SKU: 64286 - Image found
#     ✓ SKU: 64287 - Image found
#     ✓ SKU: 64288 - Image found
#     ✓ SKU: 64289 - Image found
#   Product: Canabzy Take Off Blend Disposable 3.5gm (ID: 1699) - 8 variants
#     ✓ SKU: 64385 - Image found
#     ✓ SKU: 64386 - Image found
#     ✓ SKU: 64387 - Image found
#     ✓ SKU: 64388 - Image found
#     ✓ SKU: 64389 - Image found
#     ✓ SKU: 64390 - Image found
#     ✓ SKU: 64391 - Image found
#     ✓ SKU: 64392 - Image found
#   Product: EDP 7OH 50mg Shot 12ct Box (ID: 1700) - 1 variants
#     ✓ SKU: 64484 - Image found
#   Product: Royal Relax 7Hydroxy 45mg 3ct Tablet Each (ID: 1701) - 1 variants
#     ✓ SKU: 64585 - Image found
#   Product: Slime Licker (ID: 1702) - 1 variants
#     ✓ SKU: 64587 - Image found
#   Product: Canabzy THC-A Infused Gummies 15000mg 30ct Jar (ID: 1703) - 6 variants
#     ✓ SKU: 64590 - Image found
#     ✓ SKU: 64591 - Image found
#     ✓ SKU: 64693 - Image found
#     ✓ SKU: 64694 - Image found
#     ✓ SKU: 64695 - Image found
#     ✓ SKU: 64696 - Image found
#   Product: Canabzy THC-A Infused Gummies 12000mg 2ct 24ct Box (ID: 1704) - 6 variants
#     ✓ SKU: 64688 - Image found
#     ✓ SKU: 64689 - Image found
#     ✓ SKU: 64690 - Image found
#     ✓ SKU: 64691 - Image found
#     ✓ SKU: 64692 - Image found
#     ⚠ SKU: 67977 - No variant-specific image
#   Product: EDP 7OH 40mg 2ct Tablet 12ct Box (ID: 1705) - 1 variants
#     ✓ SKU: 64789 - Image found
#   Product: Innokin GoMax 5.5ml Tank (ID: 1706) - 3 variants
#     ✓ SKU: 64796 - Image found
#     ✓ SKU: 64797 - Image found
#     ✓ SKU: 64798 - Image found
#   Product: Uwell Caliburn G3 Light 1200mAh Pod Kit (ID: 1707) - 6 variants
#     ✓ SKU: 64904 - Image found
#     ✓ SKU: 64905 - Image found
#     ✓ SKU: 64902 - Image found
#     ✓ SKU: 64903 - Image found
#     ✓ SKU: 64901 - Image found
#     ✓ SKU: 64900 - Image found
#   Product: 7Ohmz 1ct Tablet 20ct Box (ID: 1708) - 1 variants
#     ✓ SKU: 64898 - Image found
#   Product: Geekbar PULSE NICOTINE FREE (ID: 1709) - 6 variants
#     ✓ SKU: 64909 - Image found
#     ✓ SKU: 64910 - Image found
#     ✓ SKU: 64911 - Image found
#     ✓ SKU: 64912 - Image found
#     ✓ SKU: 64913 - Image found
#     ⚠ SKU: 64914 - No variant-specific image
#   Product: Mystic Labs Kratom Gummies 5pcs 6ct Box (ID: 1710) - 5 variants
#     ✓ SKU: 58778 - Image found
#     ✓ SKU: 58779 - Image found
#     ✓ SKU: 65008 - Image found
#     ✓ SKU: 65016 - Image found
#     ✓ SKU: 65015 - Image found
#   Product: NanoK MIT Kratom Extract 3ct Bag 8ct Box (ID: 1711) - 3 variants
#     ✓ SKU: 65018 - Image found
#     ✓ SKU: 65019 - Image found
#     ✓ SKU: 65020 - Image found
#   Product: NanoK MIT Kratom Gummies 15ct Bag 8ct Box (ID: 1712) - 1 variants
#     ✓ SKU: 65022 - Image found
#   Product: DigiFlavor SKY 25k Puffs (ID: 1713) - 15 variants
#     ✓ SKU: 65118 - Image found
#     ✓ SKU: 65119 - Image found
#     ✓ SKU: 65120 - Image found
#     ✓ SKU: 65121 - Image found
#     ✓ SKU: 65122 - Image found
#     ✓ SKU: 65123 - Image found
#     ✓ SKU: 65124 - Image found
#     ✓ SKU: 65125 - Image found
#     ✓ SKU: 65126 - Image found
#     ✓ SKU: 65127 - Image found
#     ✓ SKU: 65128 - Image found
#     ✓ SKU: 65129 - Image found
#     ✓ SKU: 65130 - Image found
#     ✓ SKU: 65131 - Image found
#     ✓ SKU: 66454 - Image found
#   Product: Wyn Nicotine Pouches 5ct Roll (ID: 1714) - 12 variants
#     ✓ SKU: 65218 - Image found
#     ✓ SKU: 65219 - Image found
#     ✓ SKU: 65220 - Image found
#     ✓ SKU: 65221 - Image found
#     ✓ SKU: 65222 - Image found
#     ✓ SKU: 65223 - Image found
#     ✓ SKU: 65224 - Image found
#     ✓ SKU: 65225 - Image found
#     ✓ SKU: 65226 - Image found
#     ✓ SKU: 65227 - Image found
#     ✓ SKU: 65228 - Image found
#     ✓ SKU: 65229 - Image found
#   Product: Sow Good Freeze Dried Candy 1.3oz (ID: 1715) - 1 variants
#     ✓ SKU: 58348 - Image found
#   Product: K-Pow 2ct Capsules Each (ID: 1716) - 1 variants
#     ✓ SKU: 65531 - Image found
#   Product: Geekbar Pulse X Patriot Edition 25K (ID: 1717) - 3 variants
#     ✓ SKU: 61841 - Image found
#     ✓ SKU: 61842 - Image found
#     ✓ SKU: 61843 - Image found
#   Product: Mr Fog Switch SW5500 (ID: 1718) - 35 variants
#     ✓ SKU: 65748 - Image found
#     ✓ SKU: 65749 - Image found
#     ✓ SKU: 65750 - Image found
#     ✓ SKU: 65751 - Image found
#     ✓ SKU: 65752 - Image found
#     ✓ SKU: 65753 - Image found
#     ✓ SKU: 65754 - Image found
#     ✓ SKU: 65755 - Image found
#     ✓ SKU: 65756 - Image found
#     ✓ SKU: 65757 - Image found
#     ✓ SKU: 65758 - Image found
#     ✓ SKU: 65759 - Image found
#     ✓ SKU: 65760 - Image found
#     ✓ SKU: 65761 - Image found
#     ✓ SKU: 65762 - Image found
#     ✓ SKU: 65763 - Image found
#     ✓ SKU: 65764 - Image found
#     ✓ SKU: 65765 - Image found
#     ✓ SKU: 65766 - Image found
#     ✓ SKU: 65767 - Image found
#     ✓ SKU: 65768 - Image found
#     ✓ SKU: 65769 - Image found
#     ✓ SKU: 65770 - Image found
#     ✓ SKU: 65771 - Image found
#     ✓ SKU: 65772 - Image found
#     ✓ SKU: 65773 - Image found
#     ✓ SKU: 65774 - Image found
#     ✓ SKU: 65775 - Image found
#     ✓ SKU: 65776 - Image found
#     ✓ SKU: 65777 - Image found
#     ✓ SKU: 65778 - Image found
#     ✓ SKU: 65779 - Image found
#     ✓ SKU: 65847 - Image found
#     ✓ SKU: 65848 - Image found
#     ✓ SKU: 65849 - Image found
#   Product: Cake Delta 9 + THC-A Gummies 11000mg 21ct Jar (ID: 1719) - 3 variants
#     ✓ SKU: 65948 - Image found
#     ✓ SKU: 65949 - Image found
#     ✓ SKU: 65950 - Image found
#   Product: Cake XL 6g Disposable (ID: 1720) - 10 variants
#     ✓ SKU: 65952 - Image found
#     ✓ SKU: 65953 - Image found
#     ✓ SKU: 65954 - Image found
#     ⚠ SKU: 65955 - No variant-specific image
#     ✓ SKU: 65956 - Image found
#     ✓ SKU: 65957 - Image found
#     ✓ SKU: 65958 - Image found
#     ⚠ SKU: 65959 - No variant-specific image
#     ✓ SKU: 65960 - Image found
#     ✓ SKU: 65961 - Image found
#   Product: Silly Dots Mega Dose 12000mg 3ct Tabs 10ct Box (ID: 1721) - 1 variants
#     ✓ SKU: 66053 - Image found
#   Product: 7OHMz 6ct Tablet 20ct Box (ID: 1722) - 1 variants
#     ✓ SKU: 66054 - Image found
#   Product: PureOhms 7 Hydroxy + Psudoindoxyl 30mg 4ct Tablet (ID: 1723) - 1 variants
#     ✓ SKU: 66055 - Image found
#   Product: PureOhms Black 30mg 1ct Tablet 30ct Box (ID: 1724) - 1 variants
#     ✓ SKU: 66056 - Image found
#   Product: Adjust MyCool 40K Puff (ID: 1725) - 15 variants
#     ✓ SKU: 66154 - Image found
#     ✓ SKU: 66155 - Image found
#     ✓ SKU: 66156 - Image found
#     ✓ SKU: 66157 - Image found
#     ✓ SKU: 66158 - Image found
#     ✓ SKU: 66159 - Image found
#     ✓ SKU: 66160 - Image found
#     ✓ SKU: 66161 - Image found
#     ✓ SKU: 66162 - Image found
#     ✓ SKU: 66163 - Image found
#     ✓ SKU: 66164 - Image found
#     ✓ SKU: 66165 - Image found
#     ✓ SKU: 66166 - Image found
#     ✓ SKU: 66167 - Image found
#     ✓ SKU: 66253 - Image found
#   Product: Viva Zen 2X 12ct Box (ID: 1726) - 1 variants
#     ✓ SKU: 23707 - Image found
#   Product: Geekbar Pulse X Platinum Edition | Display Box of 5 (ID: 1727) - 6 variants
#     ✓ SKU: 66456 - Image found
#     ✓ SKU: 66457 - Image found
#     ✓ SKU: 66458 - Image found
#     ✓ SKU: 66459 - Image found
#     ✓ SKU: 66460 - Image found
#     ✓ SKU: 66556 - Image found
#
# Processing page 5 - 250 products...
#   Product: GeekBar PULSE Halloween Edition (7.5k - 15k puff) (ID: 1728) - 2 variants
#     ✓ SKU: 66663 - Image found
#     ✓ SKU: 66664 - Image found
#   Product: JNR PhoneVape 30K Puffs (ID: 1729) - 10 variants
#     ✓ SKU: 66868 - Image found
#     ✓ SKU: 66864 - Image found
#     ✓ SKU: 66870 - Image found
#     ✓ SKU: 66963 - Image found
#     ✓ SKU: 66872 - Image found
#     ✓ SKU: 66867 - Image found
#     ✓ SKU: 66871 - Image found
#     ✓ SKU: 66869 - Image found
#     ✓ SKU: 66865 - Image found
#     ✓ SKU: 66866 - Image found
#   Product: Geekbar Pulse X 25K Meteor Edition (ID: 1730) - 5 variants
#     ✓ SKU: 66875 - Image found
#     ✓ SKU: 66876 - Image found
#     ✓ SKU: 66964 - Image found
#     ✓ SKU: 66874 - Image found
#     ✓ SKU: 67063 - Image found
#   Product: JNR Vape Watch 30K Puffs (ID: 1731) - 10 variants
#     ✓ SKU: 66878 - Image found
#     ✓ SKU: 66879 - Image found
#     ✓ SKU: 66880 - Image found
#     ✓ SKU: 66881 - Image found
#     ✓ SKU: 66882 - Image found
#     ✓ SKU: 66883 - Image found
#     ✓ SKU: 66884 - Image found
#     ✓ SKU: 66885 - Image found
#     ✓ SKU: 66886 - Image found
#     ✓ SKU: 66887 - Image found
#   Product: RAZ DC25000 Halloween Edition (ID: 1732) - 2 variants
#     ✓ SKU: 67166 - Image found
#     ✓ SKU: 67165 - Image found
#   Product: OPMS Liquid 50ct Box (ID: 1733) - 3 variants
#     ✓ SKU: 62663 - Image found
#     ✓ SKU: 62662 - Image found
#     ⚠ SKU: 86428 - No variant-specific image
#   Product: Half Bak'd 5G Rosin Blend SUMO Disposable (ID: 1734) - 5 variants
#     ✓ SKU: 67678 - Image found
#     ✓ SKU: 67679 - Image found
#     ✓ SKU: 67680 - Image found
#     ✓ SKU: 67681 - Image found
#     ✓ SKU: 67578 - Image found
#   Product: Press'd Hulk Blend 30mg Kratom Tablets 3ct 25ct Box (ID: 1735) - 1 variants
#     ✓ SKU: 67878 - Image found
#   Product: Press'd Red-OH 18mg Kratom Tablets 3ct 25ctBox (ID: 1736) - 1 variants
#     ✓ SKU: 67877 - Image found
#   Product: Lost Mary MO20000 PRO (ID: 1737) - 24 variants
#     ✓ SKU: 67979 - Image found
#     ✓ SKU: 67980 - Image found
#     ✓ SKU: 67981 - Image found
#     ✓ SKU: 67982 - Image found
#     ✓ SKU: 67983 - Image found
#     ✓ SKU: 67984 - Image found
#     ✓ SKU: 67985 - Image found
#     ✓ SKU: 67986 - Image found
#     ✓ SKU: 67987 - Image found
#     ✓ SKU: 67988 - Image found
#     ✓ SKU: 67989 - Image found
#     ✓ SKU: 67990 - Image found
#     ✓ SKU: 67991 - Image found
#     ✓ SKU: 67992 - Image found
#     ✓ SKU: 68078 - Image found
#     ⚠ SKU: 75976 - No variant-specific image
#     ⚠ SKU: 75977 - No variant-specific image
#     ⚠ SKU: 75978 - No variant-specific image
#     ⚠ SKU: 75979 - No variant-specific image
#     ⚠ SKU: 75980 - No variant-specific image
#     ⚠ SKU: 75981 - No variant-specific image
#     ⚠ SKU: 75983 - No variant-specific image
#     ⚠ SKU: 75985 - No variant-specific image
#     ⚠ SKU: 75986 - No variant-specific image
#   Product: Hyroxi 7-OH 10ct Pouches 5ct Roll (ID: 1738) - 2 variants
#     ✓ SKU: 68179 - Image found
#     ✓ SKU: 68180 - Image found
#   Product: Hyroxi 7-OH 15mg 5ct Tablets  20ct Box (ID: 1739) - 2 variants
#     ✓ SKU: 68278 - Image found
#     ✓ SKU: 68279 - Image found
#   Product: Adjust MyFlavor 40K Puff (ID: 1740) - 13 variants
#     ✓ SKU: 68379 - Image found
#     ✓ SKU: 68380 - Image found
#     ✓ SKU: 68478 - Image found
#     ✓ SKU: 68479 - Image found
#     ✓ SKU: 68480 - Image found
#     ✓ SKU: 68481 - Image found
#     ✓ SKU: 68482 - Image found
#     ✓ SKU: 68483 - Image found
#     ⚠ SKU: 96447 - No variant-specific image
#     ⚠ SKU: 96448 - No variant-specific image
#     ⚠ SKU: 96450 - No variant-specific image
#     ⚠ SKU: 96449 - No variant-specific image
#     ⚠ SKU: 96451 - No variant-specific image
#   Product: Digi Flavor BRK 20K Puff Disposable Pod (ID: 1741) - 8 variants
#     ✓ SKU: 68679 - Image found
#     ✓ SKU: 68678 - Image found
#     ✓ SKU: 68579 - Image found
#     ✓ SKU: 68580 - Image found
#     ✓ SKU: 68582 - Image found
#     ✓ SKU: 68581 - Image found
#     ✓ SKU: 68780 - Image found
#     ✓ SKU: 68779 - Image found
#   Product: Digi Flavor BRK Battery Device (ID: 1742) - 1 variants
#     ✓ SKU: 68583 - Image found
#   Product: KadoBar Snap 25K Puffs (ID: 1743) - 10 variants
#     ✓ SKU: 68782 - Image found
#     ✓ SKU: 68783 - Image found
#     ✓ SKU: 68784 - Image found
#     ✓ SKU: 68881 - Image found
#     ✓ SKU: 68882 - Image found
#     ✓ SKU: 68883 - Image found
#     ✓ SKU: 68884 - Image found
#     ✓ SKU: 68885 - Image found
#     ✓ SKU: 69790 - Image found
#     ⚠ SKU: 78500 - No variant-specific image
#   Product: PureOhms 7-Hydroxi 18mg 4ct Tablet 10ct Box (ID: 1744) - 2 variants
#     ✓ SKU: 68989 - Image found
#     ✓ SKU: 68990 - Image found
#   Product: Adjust MySweet 40K Puff (ID: 1745) - 6 variants
#     ✓ SKU: 69090 - Image found
#     ✓ SKU: 69091 - Image found
#     ✓ SKU: 69092 - Image found
#     ✓ SKU: 69093 - Image found
#     ✓ SKU: 69094 - Image found
#     ✓ SKU: 69095 - Image found
#   Product: Raz LTX 25K Puffs (ID: 1746) - 41 variants
#     ✓ SKU: 69190 - Image found
#     ✓ SKU: 69191 - Image found
#     ✓ SKU: 69192 - Image found
#     ✓ SKU: 69193 - Image found
#     ✓ SKU: 69194 - Image found
#     ✓ SKU: 69195 - Image found
#     ✓ SKU: 69196 - Image found
#     ✓ SKU: 69197 - Image found
#     ✓ SKU: 69198 - Image found
#     ✓ SKU: 69199 - Image found
#     ✓ SKU: 69200 - Image found
#     ✓ SKU: 69201 - Image found
#     ✓ SKU: 69202 - Image found
#     ✓ SKU: 69203 - Image found
#     ✓ SKU: 69204 - Image found
#     ✓ SKU: 69205 - Image found
#     ✓ SKU: 69206 - Image found
#     ✓ SKU: 69207 - Image found
#     ✓ SKU: 69208 - Image found
#     ✓ SKU: 69209 - Image found
#     ✓ SKU: 69210 - Image found
#     ✓ SKU: 69211 - Image found
#     ✓ SKU: 69212 - Image found
#     ✓ SKU: 69213 - Image found
#     ✓ SKU: 69214 - Image found
#     ✓ SKU: 69215 - Image found
#     ✓ SKU: 69216 - Image found
#     ✓ SKU: 69217 - Image found
#     ✓ SKU: 69218 - Image found
#     ✓ SKU: 69219 - Image found
#     ✓ SKU: 69220 - Image found
#     ✓ SKU: 69221 - Image found
#     ✓ SKU: 69222 - Image found
#     ✓ SKU: 69223 - Image found
#     ✓ SKU: 69294 - Image found
#     ✓ SKU: 69293 - Image found
#     ✓ SKU: 74543 - Image found
#     ✓ SKU: 75564 - Image found
#     ✓ SKU: 75565 - Image found
#     ⚠ SKU: 76582 - No variant-specific image
#     ⚠ SKU: 73129 - No variant-specific image
#   Product: KadoBar Snap Pod 25K Puffs (ID: 1747) - 8 variants
#     ✓ SKU: 69690 - Image found
#     ✓ SKU: 69691 - Image found
#     ✓ SKU: 69692 - Image found
#     ✓ SKU: 69693 - Image found
#     ✓ SKU: 69694 - Image found
#     ✓ SKU: 69695 - Image found
#     ✓ SKU: 69696 - Image found
#     ✓ SKU: 69789 - Image found
#   Product: KadoBar I-Pro 35K Puffs (ID: 1748) - 15 variants
#     ✓ SKU: 69698 - Image found
#     ✓ SKU: 69699 - Image found
#     ✓ SKU: 69700 - Image found
#     ✓ SKU: 69701 - Image found
#     ✓ SKU: 69702 - Image found
#     ✓ SKU: 69703 - Image found
#     ✓ SKU: 69704 - Image found
#     ✓ SKU: 69705 - Image found
#     ✓ SKU: 69706 - Image found
#     ⚠ SKU: 69707 - No variant-specific image
#     ✓ SKU: 69708 - Image found
#     ✓ SKU: 69709 - Image found
#     ✓ SKU: 69710 - Image found
#     ✓ SKU: 69711 - Image found
#     ✓ SKU: 69712 - Image found
#   Product: Vaporesso Xros 4 Nano Kit (ID: 1749) - 9 variants
#     ✓ SKU: 69990 - Image found
#     ✓ SKU: 69991 - Image found
#     ✓ SKU: 69992 - Image found
#     ✓ SKU: 69993 - Image found
#     ✓ SKU: 69994 - Image found
#     ✓ SKU: 69995 - Image found
#     ✓ SKU: 69996 - Image found
#     ✓ SKU: 69997 - Image found
#     ⚠ SKU: 82718 - No variant-specific image
#   Product: Chapo Blood Diamond 1000mg 2pk Gummies 30ct Box (ID: 1750) - 5 variants
#     ✓ SKU: 69999 - Image found
#     ✓ SKU: 70000 - Image found
#     ✓ SKU: 70001 - Image found
#     ✓ SKU: 70002 - Image found
#     ✓ SKU: 70003 - Image found
#   Product: EDP Gold Mitragyna Metabolites 30mg 2ct Tablet 12ct Box (ID: 1751) - 1 variants
#     ✓ SKU: 70090 - Image found
#   Product: Purple Enhanced Microdose Gummies 3000mg 5ct Pack 10ct Box (ID: 1752) - 7 variants
#     ✓ SKU: 70092 - Image found
#     ✓ SKU: 70093 - Image found
#     ✓ SKU: 70094 - Image found
#     ✓ SKU: 70104 - Image found
#     ⚠ SKU: 76580 - No variant-specific image
#     ⚠ SKU: 76581 - No variant-specific image
#     ⚠ SKU: 76579 - No variant-specific image
#   Product: 7 Tabz 7-Hydroxy 15mg 4ct Tablets 10ct Box (ID: 1753) - 5 variants
#     ✓ SKU: 70096 - Image found
#     ✓ SKU: 70097 - Image found
#     ✓ SKU: 70098 - Image found
#     ✓ SKU: 70099 - Image found
#     ✓ SKU: 70105 - Image found
#   Product: Opia 7 Hydroxy Kratom 20mg 4ct Tablets 10ct Box (ID: 1754) - 5 variants
#     ✓ SKU: 70101 - Image found
#     ✓ SKU: 70106 - Image found
#     ✓ SKU: 70107 - Image found
#     ✓ SKU: 73644 - Image found
#     ✓ SKU: 73648 - Image found
#   Product: 7 Tabz 7-Hydroxy + Pseudo 20mg 4ct Tablets 10ct Box (ID: 1755) - 1 variants
#     ✓ SKU: 70103 - Image found
#   Product: 7-Ohmz Gummies 3.5mg 8ct Bag - 10ct Box (ID: 1756) - 1 variants
#     ✓ SKU: 70108 - Image found
#   Product: KadoBar NI40000 Puffs (ID: 1757) - 15 variants
#     ✓ SKU: 70192 - Image found
#     ✓ SKU: 70193 - Image found
#     ✓ SKU: 70194 - Image found
#     ✓ SKU: 70291 - Image found
#     ✓ SKU: 70195 - Image found
#     ✓ SKU: 70198 - Image found
#     ✓ SKU: 70196 - Image found
#     ✓ SKU: 70199 - Image found
#     ✓ SKU: 70197 - Image found
#     ✓ SKU: 70200 - Image found
#     ✓ SKU: 70492 - Image found
#     ✓ SKU: 70493 - Image found
#     ✓ SKU: 70494 - Image found
#     ✓ SKU: 70495 - Image found
#     ✓ SKU: 70496 - Image found
#   Product: Rock It THC-P Gummies 1000mg 80ct Jar (ID: 1758) - 10 variants
#     ⚠ SKU: 70401 - No variant-specific image
#     ⚠ SKU: 70400 - No variant-specific image
#     ✓ SKU: 70398 - Image found
#     ⚠ SKU: 70397 - No variant-specific image
#     ⚠ SKU: 70399 - No variant-specific image
#     ✓ SKU: 70394 - Image found
#     ✓ SKU: 70393 - Image found
#     ✓ SKU: 70396 - Image found
#     ✓ SKU: 70392 - Image found
#     ✓ SKU: 70395 - Image found
#   Product: Rock It THC Gummies 1500mg 80ct Jar (ID: 1759) - 10 variants
#     ✓ SKU: 70404 - Image found
#     ✓ SKU: 70403 - Image found
#     ✓ SKU: 70412 - Image found
#     ✓ SKU: 70411 - Image found
#     ✓ SKU: 70410 - Image found
#     ✓ SKU: 70409 - Image found
#     ✓ SKU: 70405 - Image found
#     ✓ SKU: 70406 - Image found
#     ✓ SKU: 70408 - Image found
#     ✓ SKU: 70407 - Image found
#   Product: Chyl Nicotine Pouches Gift Box (ID: 1760) - 1 variants
#     ✓ SKU: 70201 - Image found
#   Product: TOP Rolling Paper Jar (ID: 1761) - 2 variants
#     ✓ SKU: 70498 - Image found
#     ✓ SKU: 70499 - Image found
#   Product: Geekbar Pulse X  25K NICOTINE FREE (ID: 1762) - 5 variants
#     ✓ SKU: 70599 - Image found
#     ✓ SKU: 70600 - Image found
#     ✓ SKU: 70601 - Image found
#     ✓ SKU: 70602 - Image found
#     ✓ SKU: 70603 - Image found
#   Product: Raz LTX 25K NICOTINE FREE (ID: 1763) - 5 variants
#     ✓ SKU: 70593 - Image found
#     ✓ SKU: 70594 - Image found
#     ✓ SKU: 70595 - Image found
#     ✓ SKU: 70596 - Image found
#     ✓ SKU: 70597 - Image found
#   Product: KadoBar I-Pro Holiday Edition 35K Puffs (ID: 1764) - 6 variants
#     ✓ SKU: 70697 - Image found
#     ✓ SKU: 70695 - Image found
#     ✓ SKU: 70693 - Image found
#     ✓ SKU: 70694 - Image found
#     ✓ SKU: 70696 - Image found
#     ✓ SKU: 70698 - Image found
#   Product: 7 Tabz 7-Hydroxy 15mg 1ct Tablet 40ct Box (ID: 1765) - 5 variants
#     ✓ SKU: 70809 - Image found
#     ✓ SKU: 70810 - Image found
#     ✓ SKU: 70811 - Image found
#     ✓ SKU: 70812 - Image found
# ...
#     ✓ SKU: 82621 - Image found
#     ✓ SKU: 82560 - Image found
#     ✓ SKU: 82620 - Image found
#     ✓ SKU: 82623 - Image found
#     ✓ SKU: 82622 - Image found
#     ✓ SKU: 82561 - Image found
#   Product: Smok Novo GT 1300mAh Pod Kit (ID: 2553) - 4 variants
#     ✓ SKU: 82666 - Image found
#     ✓ SKU: 82713 - Image found
#     ✓ SKU: 82712 - Image found
#     ✓ SKU: 82711 - Image found
#   Product: Yocan Dyno 1000mAh Nectar Collector (ID: 2554) - 6 variants
#     ✓ SKU: 82599 - Image found
#     ✓ SKU: 82598 - Image found
#     ✓ SKU: 82600 - Image found
#     ✓ SKU: 82597 - Image found
#     ✓ SKU: 82601 - Image found
#     ✓ SKU: 82602 - Image found
#   Product: Lost Vape Ursa Epoch 1000mAh 25W Pod Kit (ID: 2555) - 6 variants
#     ✓ SKU: 83347 - Image found
#     ✓ SKU: 83342 - Image found
#     ✓ SKU: 83344 - Image found
#     ✓ SKU: 83346 - Image found
#     ✓ SKU: 83343 - Image found
#     ✓ SKU: 83345 - Image found
#   Product: Lost Vape Centaurus E40 Max Kit (ID: 2556) - 6 variants
#     ✓ SKU: 83332 - Image found
#     ✓ SKU: 83329 - Image found
#     ✓ SKU: 83331 - Image found
#     ✓ SKU: 83334 - Image found
#     ✓ SKU: 83330 - Image found
#     ✓ SKU: 83333 - Image found
#   Product: Yocan iCan E-Rig Swirling Ariflow Kit (ID: 2557) - 6 variants
#     ✓ SKU: 82594 - Image found
#     ✓ SKU: 82593 - Image found
#     ✓ SKU: 82625 - Image found
#     ✓ SKU: 82590 - Image found
#     ✓ SKU: 82591 - Image found
#     ✓ SKU: 82592 - Image found
#   Product: Lost Vape Ursa Nano S2 1000mAh 30W Pod Kit (ID: 2558) - 9 variants
#     ✓ SKU: 83336 - Image found
#     ✓ SKU: 83337 - Image found
#     ✓ SKU: 83338 - Image found
#     ✓ SKU: 83340 - Image found
#     ✓ SKU: 83363 - Image found
#     ✓ SKU: 83362 - Image found
#     ✓ SKU: 83341 - Image found
#     ✓ SKU: 83335 - Image found
#     ✓ SKU: 83339 - Image found
#   Product: VOOPOO VRIZZ 800mAh 24W Pod Kit (ID: 2559) - 5 variants
#     ✓ SKU: 83314 - Image found
#     ✓ SKU: 83312 - Image found
#     ✓ SKU: 83313 - Image found
#     ✓ SKU: 83350 - Image found
#     ✓ SKU: 83349 - Image found
#   Product: Yocan Orbit 1700mAh Vaporizer Kit (ID: 2560) - 3 variants
#     ✓ SKU: 82615 - Image found
#     ✓ SKU: 82617 - Image found
#     ✓ SKU: 82616 - Image found
#   Product: Opia Ultra 7 Hydroxy 60mg 4pk Tablets 10ct Box (ID: 2561) - 5 variants
#     ✓ SKU: 96240 - Image found
#     ✓ SKU: 96238 - Image found
#     ✓ SKU: 96239 - Image found
#     ✓ SKU: 96236 - Image found
#     ✓ SKU: 96237 - Image found
#   Product: JOB Double Wide Papers 24ct Box (ID: 2562) - 1 variants
#     ✓ SKU: 96337 - Image found
#   Product: Lattafa Asdaaf 100ml Perfume (ID: 2563) - 1 variants
#     ✓ SKU: 86031 - Image found
#   Product: CannaBOOM 500mg D9 PP $10.99 Full Spectrum Gummies 10ct Box (ID: 2564) - 3 variants
#     ✓ SKU: 89904 - Image found
#     ✓ SKU: 89903 - Image found
#     ✓ SKU: 89905 - Image found
#   Product: Puff Panda 15000mg THC Gummies 15ct Jar (ID: 2565) - 6 variants
#     ✓ SKU: 95607 - Image found
#     ✓ SKU: 95610 - Image found
#     ✓ SKU: 95608 - Image found
#     ✓ SKU: 95605 - Image found
#     ✓ SKU: 95606 - Image found
#     ✓ SKU: 95609 - Image found
#   Product: iJoy XP50000 Disposable (ID: 2566) - 10 variants
#     ✓ SKU: 96348 - Image found
#     ✓ SKU: 96345 - Image found
#     ✓ SKU: 96342 - Image found
#     ✓ SKU: 96346 - Image found
#     ✓ SKU: 96347 - Image found
#     ✓ SKU: 96343 - Image found
#     ✓ SKU: 96341 - Image found
#     ✓ SKU: 96339 - Image found
#     ✓ SKU: 96340 - Image found
#     ✓ SKU: 96344 - Image found
#   Product: Hazy Mary Exotic THCP 1G Diamond Infused Pre-Roll 40ct Box (ID: 2567) - 6 variants
#     ✓ SKU: 96456 - Image found
#     ✓ SKU: 96457 - Image found
#     ✓ SKU: 96458 - Image found
#     ✓ SKU: 96453 - Image found
#     ✓ SKU: 96454 - Image found
#     ✓ SKU: 96455 - Image found
#   Product: Puff Panda THC-A 3.5G Snow Cap 6ct Box (ID: 2568) - 3 variants
#     ✓ SKU: 96659 - Image found
#     ✓ SKU: 96657 - Image found
#     ✓ SKU: 96658 - Image found
#   Product: Puff Panda THC-A 7G Snow Cap 6ct Box (ID: 2569) - 3 variants
#     ✓ SKU: 96661 - Image found
#     ✓ SKU: 96663 - Image found
#     ✓ SKU: 96662 - Image found
#   Product: Puff Panda THC-A 3.5G Indoor Flower 6ct Box (ID: 2570) - 3 variants
#     ✓ SKU: 96653 - Image found
#     ✓ SKU: 96655 - Image found
#     ✓ SKU: 96654 - Image found
#   Product: 7 Star 7 Hydroxy 30mg 5ct Tablets 12ct Box (ID: 2571) - 5 variants
#     ✓ SKU: 94477 - Image found
#     ✓ SKU: 94480 - Image found
#     ✓ SKU: 94481 - Image found
#     ✓ SKU: 94478 - Image found
#     ✓ SKU: 94479 - Image found
#   Product: Backwoods True Wraps 5pk 16ct Box (ID: 2572) - 1 variants
#     ✓ SKU: 98939 - Image found
#   Product: Big Dog Tobacco Broadleaf Wraps 2/$1.99 20ct Box (ID: 2573) - 1 variants
#     ✓ SKU: 98940 - Image found
#   Product: Cannabis Life THCp 1G Delta Cart (ID: 2574) - 3 variants
#     ✓ SKU: 101282 - Image found
#     ✓ SKU: 101280 - Image found
#     ✓ SKU: 101281 - Image found
#   Product: EBCreate BC PRO 40K Puffs Disposable (ID: 2575) - 1 variants
#     ⚠ SKU: 99052 - No variant-specific image
#   Product: GeekVape Digi Q Vista Kit (ID: 2576) - 8 variants
#     ⚠ SKU: 100928 - No variant-specific image
#     ⚠ SKU: 100930 - No variant-specific image
#     ⚠ SKU: 100932 - No variant-specific image
#     ⚠ SKU: 100939 - No variant-specific image
#     ⚠ SKU: 100938 - No variant-specific image
#     ⚠ SKU: 100931 - No variant-specific image
#     ⚠ SKU: 100929 - No variant-specific image
#     ⚠ SKU: 100933 - No variant-specific image
#   Product: North 5K Puffs Disposable (ID: 2577) - 24 variants
#     ⚠ SKU: 97386 - No variant-specific image
#     ⚠ SKU: 97387 - No variant-specific image
#     ⚠ SKU: 97388 - No variant-specific image
#     ⚠ SKU: 97389 - No variant-specific image
#     ⚠ SKU: 97410 - No variant-specific image
#     ⚠ SKU: 97390 - No variant-specific image
#     ⚠ SKU: 97391 - No variant-specific image
#     ⚠ SKU: 97392 - No variant-specific image
#     ⚠ SKU: 97393 - No variant-specific image
#     ⚠ SKU: 97411 - No variant-specific image
#     ⚠ SKU: 97394 - No variant-specific image
#     ⚠ SKU: 97395 - No variant-specific image
#     ⚠ SKU: 97396 - No variant-specific image
#     ⚠ SKU: 97397 - No variant-specific image
#     ⚠ SKU: 97412 - No variant-specific image
#     ⚠ SKU: 97398 - No variant-specific image
#     ⚠ SKU: 97399 - No variant-specific image
#     ⚠ SKU: 97400 - No variant-specific image
#     ⚠ SKU: 97401 - No variant-specific image
#     ⚠ SKU: 97402 - No variant-specific image
#     ⚠ SKU: 97403 - No variant-specific image
#     ⚠ SKU: 97404 - No variant-specific image
#     ⚠ SKU: 97413 - No variant-specific image
#     ⚠ SKU: 97405 - No variant-specific image
#   Product: North 5K Puffs Night Edition Disposable (ID: 2578) - 1 variants
#     ⚠ SKU: 97418 - No variant-specific image
#   Product: North 5K Puffs Patriotic Edition Disposable (ID: 2579) - 1 variants
#     ⚠ SKU: 97407 - No variant-specific image
#
# Processing page 8 - 8 products...
#   Product: Off Stamp X-Cube Crystal Cube Disposable Pod (ID: 2580) - 4 variants
#     ⚠ SKU: 100940 - No variant-specific image
#     ⚠ SKU: 100935 - No variant-specific image
#     ⚠ SKU: 100936 - No variant-specific image
#     ⚠ SKU: 100941 - No variant-specific image
#   Product: Play Deck Skateboard Battery (ID: 2581) - 8 variants
#     ⚠ SKU: 99490 - No variant-specific image
#     ⚠ SKU: 99491 - No variant-specific image
#     ⚠ SKU: 99492 - No variant-specific image
#     ⚠ SKU: 99493 - No variant-specific image
#     ⚠ SKU: 99494 - No variant-specific image
#     ⚠ SKU: 99495 - No variant-specific image
#     ⚠ SKU: 99496 - No variant-specific image
#     ⚠ SKU: 99497 - No variant-specific image
#   Product: RYL Spring Edtiion 35K Puff Disposable (ID: 2582) - 4 variants
#     ⚠ SKU: 100925 - No variant-specific image
#     ⚠ SKU: 100937 - No variant-specific image
#     ⚠ SKU: 100926 - No variant-specific image
#     ⚠ SKU: 100924 - No variant-specific image
#   Product: Smyle Penjamin Wandjamin VV 510 Battery (ID: 2583) - 2 variants
#     ⚠ SKU: 99892 - No variant-specific image
#     ⚠ SKU: 99893 - No variant-specific image
#   Product: Smyle Raygun Penjamin 400mAh VV 510 Battery (ID: 2584) - 5 variants
#     ⚠ SKU: 99884 - No variant-specific image
#     ⚠ SKU: 99911 - No variant-specific image
#     ⚠ SKU: 99885 - No variant-specific image
#     ⚠ SKU: 99886 - No variant-specific image
#     ⚠ SKU: 99887 - No variant-specific image
#   Product: Vaporesso XROS Corex 3.0 Pod 4ct box (ID: 2585) - 2 variants
#     ⚠ SKU: 100829 - No variant-specific image
#     ⚠ SKU: 100830 - No variant-specific image
#   Product: VooPoo Vinci Spark 220 Kit (ID: 2586) - 7 variants
#     ⚠ SKU: 99698 - No variant-specific image
#     ⚠ SKU: 99683 - No variant-specific image
#     ⚠ SKU: 99684 - No variant-specific image
#     ⚠ SKU: 99699 - No variant-specific image
#     ⚠ SKU: 99685 - No variant-specific image
#     ⚠ SKU: 99700 - No variant-specific image
#     ⚠ SKU: 99701 - No variant-specific image
#   Product: Yocan Flora Dry Herb Vaporizer Kit (ID: 2587) - 4 variants
#     ⚠ SKU: 99674 - No variant-specific image
#     ⚠ SKU: 99675 - No variant-specific image
#     ⚠ SKU: 99676 - No variant-specific image
#     ⚠ SKU: 99677 - No variant-specific image
#
# No more products found. Finished at page 8.
#
# ============================================================
# ✓ EXPORT COMPLETE
# ============================================================
# File saved: bigcommerce_sku_specific_images.csv
# Total records: 7638
# Unique SKUs: 7637
# SKUs with images: 5081
# SKUs without images: 2557
#
# ============================================================
# PREVIEW OF DATA:
# ============================================================
#          sku  product_id                            product_name  variant_id  image_id                                                                                                                    image_url_standard                                                                                                                   image_url_thumbnail                                                                                                                          image_url_zoom  is_thumbnail  sort_order
# 802    10027         345                         Smok Novo X Kit        8926       NaN                                                                                                                      NO VARIANT IMAGE                                                                                                                      NO VARIANT IMAGE                                                                                                                        NO VARIANT IMAGE         False           0
# 803    10031         345                         Smok Novo X Kit        8954       NaN                                                                                                                      NO VARIANT IMAGE                                                                                                                      NO VARIANT IMAGE                                                                                                                        NO VARIANT IMAGE         False           0
# 2111   10053         893                Geek Vape Aegis Solo Kit        4435   11388.0  https://cdn11.bigcommerce.com/s-6knvqcnb7q/products/893/images/11388/Geek-Vape-Aegis-Solo-Kit_4209__75614.1737109219.386.513.jpg?c=1  https://cdn11.bigcommerce.com/s-6knvqcnb7q/products/893/images/11388/Geek-Vape-Aegis-Solo-Kit_4209__75614.1737109219.220.290.jpg?c=1  https://cdn11.bigcommerce.com/s-6knvqcnb7q/products/893/images/11388/Geek-Vape-Aegis-Solo-Kit_4209__75614.1737109219.1280.1280.jpg?c=1          True           0
# 794    10063         328                 Yocan Vane Dry Herb Kit       15841       NaN                                                                                                                      NO VARIANT IMAGE                                                                                                                      NO VARIANT IMAGE                                                                                                                        NO VARIANT IMAGE         False           0
# 792    10064         328                 Yocan Vane Dry Herb Kit       15232       NaN                                                                                                                      NO VARIANT IMAGE                                                                                                                      NO VARIANT IMAGE                                                                                                                        NO VARIANT IMAGE         False           0
# 793    10066         328                 Yocan Vane Dry Herb Kit       15238       NaN                                                                                                                      NO VARIANT IMAGE                                                                                                                      NO VARIANT IMAGE                                                                                                                        NO VARIANT IMAGE         False           0
# 791    10067         328                 Yocan Vane Dry Herb Kit       15213       NaN                                                                                                                      NO VARIANT IMAGE                                                                                                                      NO VARIANT IMAGE                                                                                                                        NO VARIANT IMAGE         False           0
# 7625  100829        2585    Vaporesso XROS Corex 3.0 Pod 4ct box       18131       NaN                                                                                                                      NO VARIANT IMAGE                                                                                                                      NO VARIANT IMAGE                                                                                                                        NO VARIANT IMAGE         False           0
# 7626  100830        2585    Vaporesso XROS Corex 3.0 Pod 4ct box       18132       NaN                                                                                                                      NO VARIANT IMAGE                                                                                                                      NO VARIANT IMAGE                                                                                                                        NO VARIANT IMAGE         False           0
# 7617  100924        2582  RYL Spring Edtiion 35K Puff Disposable       18120       NaN                                                                                                                      NO VARIANT IMAGE                                                                                                                      NO VARIANT IMAGE                                                                                                                        NO VARIANT IMAGE         False           0
#
# ============================================================
# SAMPLE SKUs:
# ============================================================
#
# SKU: 10027
#   Product: Smok Novo X Kit
#   Variant ID: 8926
#   Image: NO VARIANT IMAGE...
#
# SKU: 10031
#   Product: Smok Novo X Kit
#   Variant ID: 8954
#   Image: NO VARIANT IMAGE...
#
# SKU: 10053
#   Product: Geek Vape Aegis Solo Kit
#   Variant ID: 4435
#   Image: https://cdn11.bigcommerce.com/s-6knvqcnb7q/products/893/images/11388/Geek-Vape-A...
#
# SKU: 10063
#   Product: Yocan Vane Dry Herb Kit
#   Variant ID: 15841
#   Image: NO VARIANT IMAGE...
#
# SKU: 10064
#   Product: Yocan Vane Dry Herb Kit
#   Variant ID: 15232
#   Image: NO VARIANT IMAGE...
#
# ============================================================
# Creating summary report...
# ✓ Summary saved to 'sku_images_summary.csv'
#
# End Time: 2025-11-13 23:01:57
# ============================================================
